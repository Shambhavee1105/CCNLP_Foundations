# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download("vader_lexicon")
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\Shambhavee
# [nltk_data]     Gune\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
text = "The experience was absolutely wonderful and I am very happy with the service."
sia = SentimentIntensityAnalyzer()
score = sia.polarity_scores(text)
print("Text: ", text)
print("Sentiment Score: ", score)
if score['compound'] >= 0.05:
    print("Positive sentiment")
elif score['compound'] <= -0.05:
    print("Negative sentiment")
else:
    print("Neutral sentiment")
# Out:
# Text:  The experience was absolutely wonderful and I am very happy with the service.
# Sentiment Score:  {'neg': 0.0, 'neu': 0.556, 'pos': 0.444, 'compound': 0.8396}
# Positive sentiment

# %%
text = "The package was completely damaged and the product quality was very poor."
sia = SentimentIntensityAnalyzer()
score = sia.polarity_scores(text)
print("Text: ", text)
print("Sentiment Score: ", score)
if score['compound'] >= 0.05:
    print("Positive sentiment")
elif score['compound'] <= -0.05:
    print("Negative sentiment")
else:
    print("Neutral sentiment")
# Out:
# Text:  The package was completely damaged and the product quality was very poor.
# Sentiment Score:  {'neg': 0.397, 'neu': 0.603, 'pos': 0.0, 'compound': -0.764}
# Negative sentiment

# %%
text = "The meeting is scheduled for 10 AM tomorrow in the conference room."
sia = SentimentIntensityAnalyzer()
score = sia.polarity_scores(text)
print("Text: ", text)
print("Sentiment Score: ", score)
if score['compound'] >= 0.05:
    print("Positive sentiment")
elif score['compound'] <= -0.05:
    print("Negative sentiment")
else:
    print("Neutral sentiment")
# Out:
# Text:  The meeting is scheduled for 10 AM tomorrow in the conference room.
# Sentiment Score:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Neutral sentiment
