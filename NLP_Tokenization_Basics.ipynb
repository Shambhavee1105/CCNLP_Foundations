# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python --version
# Out:
# Python 3.10.0

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Shambhavee
# [nltk_data]     Gune\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Shambhavee
# [nltk_data]     Gune\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Shambhavee
# [nltk_data]     Gune\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Shambhavee
# [nltk_data]     Gune\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Shambhavee Gune\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
#word tokenization
from nltk.tokenize import word_tokenize
text1 = "Cognitive Computing and Natural Language Processing is interesting."
word_tokenize(text1)
# Out:
# ['Cognitive',
#  'Computing',
#  'and',
#  'Natural',
#  'Language',
#  'Processing',
#  'is',
#  'interesting',
#  '.']

# %%
len(word_tokenize(text1))
# Out:
# 9

# %%
text2 = "Welcome to MIT_WPU."
word_tokenize(text2)
# Out:
# ['Welcome', 'to', 'MIT_WPU', '.']

# %%
len(word_tokenize(text2))
# Out:
# 4

# %%
#sentence tokenization
from nltk.tokenize import sent_tokenize
text3 = "Python is powerful. It helps in NLP. Also, AI and ML can be implemented efficiently using Python."
sent_tokenize(text3)
# Out:
# ['Python is powerful.',
#  'It helps in NLP.',
#  'Also, AI and ML can be implemented efficiently using Python.']

# %%
len(sent_tokenize(text3))
# Out:
# 3

# %%
text4 = "Python is powerful. It helps in NLP."
sent_tokenize(text4)
# Out:
# ['Python is powerful.', 'It helps in NLP.']

# %%
len(sent_tokenize(text4))
# Out:
# 2

# %%
text5 = "Python is powerful, it helps in NLP. Also, AI and ML can be implemented efficiently using Python."
sent_tokenize(text5)
# Out:
# ['Python is powerful, it helps in NLP.',
#  'Also, AI and ML can be implemented efficiently using Python.']

# %%
len(sent_tokenize(text5))
# Out:
# 2

# %%
text5 = "Python is powerful. It helps in NLP! Also, AI and ML can be implemented efficiently using Python."
sent_tokenize(text5)
# Out:
# ['Python is powerful.',
#  'It helps in NLP!',
#  'Also, AI and ML can be implemented efficiently using Python.']

# %%
text6 = "He is a Dr.! He treats cancer patients."
sent_tokenize(text6)
# Out:
# ['He is a Dr.!', 'He treats cancer patients.']

# %%
len(sent_tokenize(text6))
# Out:
# 2

# %%
text7 = "He is  Dr. Kulkarni"
sent_tokenize(text7)
# Out:
# ['He is  Dr. Kulkarni']

# %%
text8 = "python version is 3.8. It supports NLTK. It is powerful,"
sent_tokenize(text8)
# Out:
# ['python version is 3.8.', 'It supports NLTK.', 'It is powerful,']

# %%
len(sent_tokenize(text8))
# Out:
# 3

# %%
#stopwords(non-meaningful words) removal
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
text9 = "This is not an example of showing stopword removal."
words = word_tokenize(text9)
stop_words = set(stopwords.words('english'))
filtered_words = [w for w in words if w.lower() not in stop_words]
filtered_words
# Out:
# ['example', 'showing', 'stopword', 'removal', '.']

# %%
len(text9)
# Out:
# 51

# %%
len(sent_tokenize(text9))
# Out:
# 1

# %%
len(word_tokenize(text9))
# Out:
# 10

# %%
len(filtered_words)
# Out:
# 5

# %%
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to C:\Users\Shambhavee
# [nltk_data]     Gune\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\gutenberg.zip.
# True

# %%
from nltk.corpus import gutenberg
gutenberg.fileids()
hamlet = gutenberg.words('shakespeare-hamlet.txt')
hamlet[1:100]
# Out:
# ['The',
#  'Tragedie',
#  'of',
#  'Hamlet',
#  'by',
#  'William',
#  'Shakespeare',
#  '1599',
#  ']',
#  'Actus',
#  'Primus',
#  '.',
#  'Scoena',
#  'Prima',
#  '.',
#  'Enter',
#  'Barnardo',
#  'and',
#  'Francisco',
#  'two',
#  'Centinels',
#  '.',
#  'Barnardo',
#  '.',
#  'Who',
#  "'",
#  's',
#  'there',
#  '?',
#  'Fran',
#  '.',
#  'Nay',
#  'answer',
#  'me',
#  ':',
#  'Stand',
#  '&',
#  'vnfold',
#  'your',
#  'selfe',
#  'Bar',
#  '.',
#  'Long',
#  'liue',
#  'the',
#  'King',
#  'Fran',
#  '.',
#  'Barnardo',
#  '?',
#  'Bar',
#  '.',
#  'He',
#  'Fran',
#  '.',
#  'You',
#  'come',
#  'most',
#  'carefully',
#  'vpon',
#  'your',
#  'houre',
#  'Bar',
#  '.',
#  "'",
#  'Tis',
#  'now',
#  'strook',
#  'twelue',
#  ',',
#  'get',
#  'thee',
#  'to',
#  'bed',
#  'Francisco',
#  'Fran',
#  '.',
#  'For',
#  'this',
#  'releefe',
#  'much',
#  'thankes',
#  ':',
#  "'",
#  'Tis',
#  'bitter',
#  'cold',
#  ',',
#  'And',
#  'I',
#  'am',
#  'sicke',
#  'at',
# ...
